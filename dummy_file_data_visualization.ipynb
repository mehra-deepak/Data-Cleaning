# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data =pd.read_csv("dummy.csv")

# %%
data
# Out:
#        Sno                  Id  \
# 0        0  02s1r00001acKkkAAE
# 1        1  02s1r00001blgJyAAI
# 2        2  02s1r00001blgcRAAQ
# 3        3  02s1r00001blj0aAAA
# 4        4  02s1r00001blj6TAAQ
# 5        5  02s1r00001blwqoAAA
# 6        6  02s1r00001blz0lAAA
# 7        7  02s1r00001bm0GBAAY
# 8        8  02s1r00001bm0JoAAI
# 9        9  02s1r00001bm1QWAAY
# 10      10  02s1r00001bm2gQAAQ
# 11      11  02s1r00001bm2hiAAA
# 12      12  02s1r00001bm43LAAQ
# 13      13  02s1r00001bm43aAAA
# 14      14  02s1r00001bm4yCAAQ
# 15      15  02s1r00001bm4yMAAQ
# 16      16  02s1r00001bm5uuAAA
# 17      17  02s1r00001bmBRoAAM
# 18      18  02s1r00001bmBy9AAE
# 19      19  02s1r00001bmCAjAAM
# 20      20  02s1r00001bmEbwAAE
# 21      21  02s1r00001bmFdZAAU
# 22      22  02s1r00001bmFdyAAE
# 23      23  02s1r00001bmFerAAE
# 24      24  02s1r00001bmGK9AAM
# 25      25  02s1r00001bmGc3AAE
# 26      26  02s1r00001bmILnAAM
# 27      27  02s1r00001bmIhjAAE
# 28      28  02s1r00001bmIqCAAU
# 29      29  02s1r00001bmIunAAE
# ...    ...                 ...
# 8714  8714  02s1r00001iJLMQAA4
# 8715  8715  02s1r00001iJM64AAG
# 8716  8716  02s1r00001iJMXKAA4
# 8717  8717  02s1r00001iJMrFAAW
# 8718  8718  02s1r00001iJMxXAAW
# 8719  8719  02s1r00001iJN0RAAW
# 8720  8720  02s1r00001iJOIMAA4
# 8721  8721  02s1r00001iJOIlAAO
# 8722  8722  02s1r00001iJOS7AAO
# 8723  8723  02s1r00001iJP0YAAW
# 8724  8724  02s1r00001iJP6MAAW
# 8725  8725  02s1r00001iJPHtAAO
# 8726  8726  02s1r00001iJPeYAAW
# 8727  8727  02s1r00001iJPfHAAW
# 8728  8728  02s1r00001iJPlUAAW
# 8729  8729  02s1r00001iJQ3nAAG
# 8730  8730  02s1r00001iJQ5oAAG
# 8731  8731  02s1r00001iJQ7BAAW
# 8732  8732  02s1r00001iJQXRAA4
# 8733  8733  02s1r00001iJR45AAG
# 8734  8734  02s1r00001iJRFIAA4
# 8735  8735  02s1r00001iJRVkAAO
# 8736  8736  02s1r00001iJReNAAW
# 8737  8737  02s1r00001iJRrgAAG
# 8738  8738  02s1r00001iJRvnAAG
# 8739  8739  02s1r00001iJRwWAAW
# 8740  8740  02s1r00001iJRxeAAG
# 8741  8741  02s1r00001iJRzuAAG
# 8742  8742  02s1r00001iJS88AAG
# 8743  8743  02s1r00001iJSFYAA4
#
#                                                HtmlBody  \
# 0     good morning,\nplease could i have a response ...
# 1     please find attached copy of statement/queries...
# 2     hayley waterman\nkone plc\nexpense/accounts as...
# 3     dear requester,\nthank you for writing to us. ...
# 4     dear requester,\nthank you for writing to us. ...
# 5     dear sirs.\nplease respond with regards to the...
# 6     dear requester,\nthank you for writing to us. ...
# 7     dear requester,\nthank you for writing to us. ...
# 8     dear requester,\nthank you for writing to us. ...
# 9     dear requester,\nthank you for writing to us. ...
# 10    dear requester,\nthank you for writing to us. ...
# 11    good afternoon,\nplease see the attached email...
# 12    from:\ncontactap_uk@kone.com\nsent:\ntuesday, ...
# 13    from:\ncontactap_uk@kone.com\nsent:\ntuesday, ...
# 14    from:\ncontactap_uk@kone.com\nsent:\ntuesday, ...
# 15    from:\ncontactap_uk@kone.com\nsent:\ntuesday, ...
# 16    good afternoon\ncould you please advise if the...
# 17    hello all,\nplease could you deal with the cus...
# 18    dear requester,\nthank you for writing to us. ...
# 19    from:\nanderson wendy \nsent:\n29 january 2019...
# 20    the accounts department is working part time h...
# 21    dear requester,\nthank you for writing to us. ...
# 22    dear requester,\nthank you for writing to us. ...
# 23    hello,\nplease find in attach the invoice no 1...
# 24    dear requester,\nthank you for writing to us. ...
# 25    dear requester,\nthank you for writing to us. ...
# 26    dear requester,\nthank you for writing to us. ...
# 27    hi\ni don’t know how to do this\nregards\ndere...
# 28    dear requester,\nthank you for writing to us. ...
# 29    dear requester,\nthank you for writing to us. ...
# ...                                                 ...
# 8714                                                NaN
# 8715  hi,\nplease come back to me, there was nothing...
# 8716  good morning\ni have looked at your purchase o...
# 8717  hi team,\nplease check with sharon kennedy reg...
# 8718                                                NaN
# 8719                                                NaN
# 8720  hello\nwe do not know what this in reference t...
# 8721  warning:\nthe sender of this email could not b...
# 8722  hi bhanu,\ncould you please chase this again a...
# 8723                                                NaN
# 8724  we need an urgent response. especially the feb...
# 8725  hi team,\nas we have posted with incorrect dat...
# 8726  posted\nfrom:\ncontact ap_uk [mailto:contactap...
# 8727                                                NaN
# 8728                                                NaN
# 8729  as previously stated i do not complete cis sta...
# 8730  as previously stated i do not complete cis sta...
# 8731  as previously commented i do not complete cis ...
# 8732  dear requester,\nthank you for writing to us. ...
# 8733                                                NaN
# 8734                                                NaN
# 8735  please see attached statement  from widestripe...
# 8736  hi,\ncould you please push back to the vendor,...
# 8737  good afternoon, \nplease find account statemen...
# 8738  great. \nmany thanks for your prompt reply. \n...
# 8739  hi all, \nmany thanks for your recent remittan...
# 8740  hi,\nplease see attached\nkind regards\njustin...
# 8741                                                NaN
# 8742  dear requester,\nthank you for writing to us. ...
# 8743  morning,\nnot sure why you’ve emailed me – thi...
#
#                                    HtmlBody(Clean Data) Predicted Class  \
# 0     payment query good morning, thank you for your...          Others
# 1     statement & queries please find attached up to...          Status
# 2     statement from oasis products vending services...          Others
# 3     ees uk cis deductions hi, after speaking to sh...          Others
# 4     securitas invoice processed twice in error hi ...          Others
# 5     overdue invoice for vendor AHD_NUMBER please a...          Status
# 6     problem hi supplier number AHD_NUMBER problem ...          Others
# 7     cis payment hi can you please solve this probl...      Escalation
# 8     cis payment hi can you please solve this probl...      Escalation
# 9     invoice AHD_NUMBER from control applications l...          Others
# 10    invoices vendor number AHD_ALPHANUM can we kno...          Status
# 11    good afternoon, please see the attached email ...          Others
# 12    securitas invoice processed twice in error hi ...          Others
# 13    securitas invoice processed twice in error hi ...          Others
# 14    payment query good morning, thank you for your...          Others
# 15    payment query good morning, thank you for your...          Others
# 16    good afternoon could you please advise if the ...          Status
# 17    norton?s outstanding monies avtar can i please...          Others
# 18    query hello queries , st query the above two i...          Others
# 19    unpaid invoices morning wendy, could you have ...          Others
# 20    the accounts department is working part time h...          Others
# 21     invoices no AHD_DATE elevators uk limited- ko...          Others
# 22     invoices no AHD_DATE elevators uk limited- ko...          Others
# 23    hello, please find in attach the invoice no AH...          Others
# 24    neopost invoice query hi all, the document bel...          Others
# 25    neopost invoice to be deleted hi all, the docu...          Others
# 26    overdue credit note and invoices importance: h...          Others
# 27    invoice AHD_NUMBER from control applications l...          Others
# 28    kone plc good afternoon, please can you confir...          Status
# 29    over due and due invoices for payment good aft...      Escalation
# ...                                                 ...             ...
# 8714                                                NaN          Others
# 8715  outstanding items dear all, i have been chasin...      Escalation
# 8716  invoice AHD_NUMBER good afternoon please find ...          Status
# 8717  hi team, please check with sharon kennedy rega...          Others
# 8718                                                NaN          Others
# 8719                                                NaN          Others
# 8720   sub: thank you for your request:  gunnebo sta...          Others
# 8721  warning: the sender of this email could not be...          Others
# 8722                    copy of invoice AHD_NUMBER null          Others
# 8723                                                NaN          Others
# 8724  we need an urgent response. especially the feb...          Others
# 8725  over deducted cis payments good morning it is ...          Others
# 8726                                 c&r lifts services          Others
# 8727                                                NaN          Others
# 8728                                                NaN          Others
# 8729  cis statement AHD_NUMBER AHD_ALPHANUM to AHD_N...          Others
# 8730  cis statement AHD_NUMBER AHD_ALPHANUM to AHD_N...          Others
# 8731  cis statement AHD_NUMBER AHD_ALPHANUM to AHD_N...          Others
# 8732                           eagle overseas statement          Others
# 8733                                                NaN          Others
# 8734                                                NaN          Others
# 8735                                     kone statement          Others
# 8736  hi, could you please push back to the vendor, ...          Others
# 8737  good afternoon, please find account statement ...          Others
# 8738  gs culleton - invoicing error good morning, i ...          Others
# 8739  hi all, many thanks for your recent remittance...          Status
# 8740  AHD_ALPHANUM hi team, please push back to vend...          Others
# 8741                                                NaN          Others
# 8742  invoice hi ian, we have another invoice which ...          Others
# 8743  AHD_NUMBER urgent letters received at keighley...          Others
#
#       Predicted Score
# 0               100.0
# 1                95.0
# 2               100.0
# 3               100.0
# 4               100.0
# 5                95.0
# 6               100.0
# 7                62.0
# 8                62.0
# 9               100.0
# 10               95.0
# 11              100.0
# 12              100.0
# 13              100.0
# 14              100.0
# 15              100.0
# 16               95.0
# 17              100.0
# 18              100.0
# 19              100.0
# 20              100.0
# 21              100.0
# 22              100.0
# 23              100.0
# 24              100.0
# 25              100.0
# 26              100.0
# 27              100.0
# 28               95.0
# 29               67.0
# ...               ...
# 8714            100.0
# 8715             73.0
# 8716             90.0
# 8717            100.0
# 8718            100.0
# 8719            100.0
# 8720            100.0
# 8721            100.0
# 8722            100.0
# 8723            100.0
# 8724            100.0
# 8725            100.0
# 8726            100.0
# 8727            100.0
# 8728            100.0
# 8729            100.0
# 8730            100.0
# 8731            100.0
# 8732            100.0
# 8733            100.0
# 8734            100.0
# 8735            100.0
# 8736            100.0
# 8737            100.0
# 8738            100.0
# 8739             85.0
# 8740            100.0
# 8741            100.0
# 8742            100.0
# 8743            100.0
#
# [8744 rows x 6 columns]

# %%
data.describe()
# Out:
#               Sno  Predicted Score
# count  8744.00000      8744.000000
# mean   4371.50000        97.634902
# std    2524.31971         7.963307
# min       0.00000        50.000000
# 25%    2185.75000       100.000000
# 50%    4371.50000       100.000000
# 75%    6557.25000       100.000000
# max    8743.00000       100.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8744 entries, 0 to 8743
# Data columns (total 6 columns):
# Sno                     8744 non-null int64
# Id                      8744 non-null object
# HtmlBody                6907 non-null object
# HtmlBody(Clean Data)    6881 non-null object
# Predicted Class         8744 non-null object
# Predicted Score         8744 non-null float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 410.0+ KB

# %%
data.isna()
# Out:
#         Sno     Id  HtmlBody  HtmlBody(Clean Data)  Predicted Class  \
# 0     False  False     False                 False            False
# 1     False  False     False                 False            False
# 2     False  False     False                 False            False
# 3     False  False     False                 False            False
# 4     False  False     False                 False            False
# 5     False  False     False                 False            False
# 6     False  False     False                 False            False
# 7     False  False     False                 False            False
# 8     False  False     False                 False            False
# 9     False  False     False                 False            False
# 10    False  False     False                 False            False
# 11    False  False     False                 False            False
# 12    False  False     False                 False            False
# 13    False  False     False                 False            False
# 14    False  False     False                 False            False
# 15    False  False     False                 False            False
# 16    False  False     False                 False            False
# 17    False  False     False                 False            False
# 18    False  False     False                 False            False
# 19    False  False     False                 False            False
# 20    False  False     False                 False            False
# 21    False  False     False                 False            False
# 22    False  False     False                 False            False
# 23    False  False     False                 False            False
# 24    False  False     False                 False            False
# 25    False  False     False                 False            False
# 26    False  False     False                 False            False
# 27    False  False     False                 False            False
# 28    False  False     False                 False            False
# 29    False  False     False                 False            False
# ...     ...    ...       ...                   ...              ...
# 8714  False  False      True                  True            False
# 8715  False  False     False                 False            False
# 8716  False  False     False                 False            False
# 8717  False  False     False                 False            False
# 8718  False  False      True                  True            False
# 8719  False  False      True                  True            False
# 8720  False  False     False                 False            False
# 8721  False  False     False                 False            False
# 8722  False  False     False                 False            False
# 8723  False  False      True                  True            False
# 8724  False  False     False                 False            False
# 8725  False  False     False                 False            False
# 8726  False  False     False                 False            False
# 8727  False  False      True                  True            False
# 8728  False  False      True                  True            False
# 8729  False  False     False                 False            False
# 8730  False  False     False                 False            False
# 8731  False  False     False                 False            False
# 8732  False  False     False                 False            False
# 8733  False  False      True                  True            False
# 8734  False  False      True                  True            False
# 8735  False  False     False                 False            False
# 8736  False  False     False                 False            False
# 8737  False  False     False                 False            False
# 8738  False  False     False                 False            False
# 8739  False  False     False                 False            False
# 8740  False  False     False                 False            False
# 8741  False  False      True                  True            False
# 8742  False  False     False                 False            False
# 8743  False  False     False                 False            False
#
#       Predicted Score
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# 5               False
# 6               False
# 7               False
# 8               False
# 9               False
# 10              False
# 11              False
# 12              False
# 13              False
# 14              False
# 15              False
# 16              False
# 17              False
# 18              False
# 19              False
# 20              False
# 21              False
# 22              False
# 23              False
# 24              False
# 25              False
# 26              False
# 27              False
# 28              False
# 29              False
# ...               ...
# 8714            False
# 8715            False
# 8716            False
# 8717            False
# 8718            False
# 8719            False
# 8720            False
# 8721            False
# 8722            False
# 8723            False
# 8724            False
# 8725            False
# 8726            False
# 8727            False
# 8728            False
# 8729            False
# 8730            False
# 8731            False
# 8732            False
# 8733            False
# 8734            False
# 8735            False
# 8736            False
# 8737            False
# 8738            False
# 8739            False
# 8740            False
# 8741            False
# 8742            False
# 8743            False
#
# [8744 rows x 6 columns]

# %%
data.isnull().sum().sum()
# Out:
# 3700

# %%
data.isnull().sum()
# Out:
# Sno                        0
# Id                         0
# HtmlBody                1837
# HtmlBody(Clean Data)    1863
# Predicted Class            0
# Predicted Score            0
# dtype: int64

# %%
data.isnull().values.any()
# Out:
# True

# %%
# %matplotlib inline
import scattertext as st
import re, io
from pprint import pprint
import pandas as pd
import numpy as np
from scipy.stats import rankdata, hmean, norm
import spacy
import os, pkgutil, json, urllib
from urllib.request import urlopen
from IPython.display import IFrame
from IPython.core.display import display, HTML
from scattertext import CorpusFromPandas, produce_scattertext_explorer
display(HTML("&lt;style>.container { width:98% !important; }&lt;/style>"))
# Out:
# &lt;style>.container { width:98% !important; }&lt;/style>

# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
df= pd.read_csv("dummy.csv")

# %%
df=df.rename(columns={'HtmlBody(Clean Data)':'text'})

# %%
df
# Out:
#        Sno                  Id  \
# 0        0  02s1r00001acKkkAAE
# 1        1  02s1r00001blgJyAAI
# 2        2  02s1r00001blgcRAAQ
# 3        3  02s1r00001blj0aAAA
# 4        4  02s1r00001blj6TAAQ
# 5        5  02s1r00001blwqoAAA
# 6        6  02s1r00001blz0lAAA
# 7        7  02s1r00001bm0GBAAY
# 8        8  02s1r00001bm0JoAAI
# 9        9  02s1r00001bm1QWAAY
# 10      10  02s1r00001bm2gQAAQ
# 11      11  02s1r00001bm2hiAAA
# 12      12  02s1r00001bm43LAAQ
# 13      13  02s1r00001bm43aAAA
# 14      14  02s1r00001bm4yCAAQ
# 15      15  02s1r00001bm4yMAAQ
# 16      16  02s1r00001bm5uuAAA
# 17      17  02s1r00001bmBRoAAM
# 18      18  02s1r00001bmBy9AAE
# 19      19  02s1r00001bmCAjAAM
# 20      20  02s1r00001bmEbwAAE
# 21      21  02s1r00001bmFdZAAU
# 22      22  02s1r00001bmFdyAAE
# 23      23  02s1r00001bmFerAAE
# 24      24  02s1r00001bmGK9AAM
# 25      25  02s1r00001bmGc3AAE
# 26      26  02s1r00001bmILnAAM
# 27      27  02s1r00001bmIhjAAE
# 28      28  02s1r00001bmIqCAAU
# 29      29  02s1r00001bmIunAAE
# ...    ...                 ...
# 8714  8714  02s1r00001iJLMQAA4
# 8715  8715  02s1r00001iJM64AAG
# 8716  8716  02s1r00001iJMXKAA4
# 8717  8717  02s1r00001iJMrFAAW
# 8718  8718  02s1r00001iJMxXAAW
# 8719  8719  02s1r00001iJN0RAAW
# 8720  8720  02s1r00001iJOIMAA4
# 8721  8721  02s1r00001iJOIlAAO
# 8722  8722  02s1r00001iJOS7AAO
# 8723  8723  02s1r00001iJP0YAAW
# 8724  8724  02s1r00001iJP6MAAW
# 8725  8725  02s1r00001iJPHtAAO
# 8726  8726  02s1r00001iJPeYAAW
# 8727  8727  02s1r00001iJPfHAAW
# 8728  8728  02s1r00001iJPlUAAW
# 8729  8729  02s1r00001iJQ3nAAG
# 8730  8730  02s1r00001iJQ5oAAG
# 8731  8731  02s1r00001iJQ7BAAW
# 8732  8732  02s1r00001iJQXRAA4
# 8733  8733  02s1r00001iJR45AAG
# 8734  8734  02s1r00001iJRFIAA4
# 8735  8735  02s1r00001iJRVkAAO
# 8736  8736  02s1r00001iJReNAAW
# 8737  8737  02s1r00001iJRrgAAG
# 8738  8738  02s1r00001iJRvnAAG
# 8739  8739  02s1r00001iJRwWAAW
# 8740  8740  02s1r00001iJRxeAAG
# 8741  8741  02s1r00001iJRzuAAG
# 8742  8742  02s1r00001iJS88AAG
# 8743  8743  02s1r00001iJSFYAA4
#
#                                                HtmlBody  \
# 0     good morning,\nplease could i have a response ...
# 1     please find attached copy of statement/queries...
# 2     hayley waterman\nkone plc\nexpense/accounts as...
# 3     dear requester,\nthank you for writing to us. ...
# 4     dear requester,\nthank you for writing to us. ...
# 5     dear sirs.\nplease respond with regards to the...
# 6     dear requester,\nthank you for writing to us. ...
# 7     dear requester,\nthank you for writing to us. ...
# 8     dear requester,\nthank you for writing to us. ...
# 9     dear requester,\nthank you for writing to us. ...
# 10    dear requester,\nthank you for writing to us. ...
# 11    good afternoon,\nplease see the attached email...
# 12    from:\ncontactap_uk@kone.com\nsent:\ntuesday, ...
# 13    from:\ncontactap_uk@kone.com\nsent:\ntuesday, ...
# 14    from:\ncontactap_uk@kone.com\nsent:\ntuesday, ...
# 15    from:\ncontactap_uk@kone.com\nsent:\ntuesday, ...
# 16    good afternoon\ncould you please advise if the...
# 17    hello all,\nplease could you deal with the cus...
# 18    dear requester,\nthank you for writing to us. ...
# 19    from:\nanderson wendy \nsent:\n29 january 2019...
# 20    the accounts department is working part time h...
# 21    dear requester,\nthank you for writing to us. ...
# 22    dear requester,\nthank you for writing to us. ...
# 23    hello,\nplease find in attach the invoice no 1...
# 24    dear requester,\nthank you for writing to us. ...
# 25    dear requester,\nthank you for writing to us. ...
# 26    dear requester,\nthank you for writing to us. ...
# 27    hi\ni don’t know how to do this\nregards\ndere...
# 28    dear requester,\nthank you for writing to us. ...
# 29    dear requester,\nthank you for writing to us. ...
# ...                                                 ...
# 8714                                                NaN
# 8715  hi,\nplease come back to me, there was nothing...
# 8716  good morning\ni have looked at your purchase o...
# 8717  hi team,\nplease check with sharon kennedy reg...
# 8718                                                NaN
# 8719                                                NaN
# 8720  hello\nwe do not know what this in reference t...
# 8721  warning:\nthe sender of this email could not b...
# 8722  hi bhanu,\ncould you please chase this again a...
# 8723                                                NaN
# 8724  we need an urgent response. especially the feb...
# 8725  hi team,\nas we have posted with incorrect dat...
# 8726  posted\nfrom:\ncontact ap_uk [mailto:contactap...
# 8727                                                NaN
# 8728                                                NaN
# 8729  as previously stated i do not complete cis sta...
# 8730  as previously stated i do not complete cis sta...
# 8731  as previously commented i do not complete cis ...
# 8732  dear requester,\nthank you for writing to us. ...
# 8733                                                NaN
# 8734                                                NaN
# 8735  please see attached statement  from widestripe...
# 8736  hi,\ncould you please push back to the vendor,...
# 8737  good afternoon, \nplease find account statemen...
# 8738  great. \nmany thanks for your prompt reply. \n...
# 8739  hi all, \nmany thanks for your recent remittan...
# 8740  hi,\nplease see attached\nkind regards\njustin...
# 8741                                                NaN
# 8742  dear requester,\nthank you for writing to us. ...
# 8743  morning,\nnot sure why you’ve emailed me – thi...
#
#                                                    text Predicted Class  \
# 0     payment query good morning, thank you for your...          Others
# 1     statement & queries please find attached up to...          Status
# 2     statement from oasis products vending services...          Others
# 3     ees uk cis deductions hi, after speaking to sh...          Others
# 4     securitas invoice processed twice in error hi ...          Others
# 5     overdue invoice for vendor AHD_NUMBER please a...          Status
# 6     problem hi supplier number AHD_NUMBER problem ...          Others
# 7     cis payment hi can you please solve this probl...      Escalation
# 8     cis payment hi can you please solve this probl...      Escalation
# 9     invoice AHD_NUMBER from control applications l...          Others
# 10    invoices vendor number AHD_ALPHANUM can we kno...          Status
# 11    good afternoon, please see the attached email ...          Others
# 12    securitas invoice processed twice in error hi ...          Others
# 13    securitas invoice processed twice in error hi ...          Others
# 14    payment query good morning, thank you for your...          Others
# 15    payment query good morning, thank you for your...          Others
# 16    good afternoon could you please advise if the ...          Status
# 17    norton?s outstanding monies avtar can i please...          Others
# 18    query hello queries , st query the above two i...          Others
# 19    unpaid invoices morning wendy, could you have ...          Others
# 20    the accounts department is working part time h...          Others
# 21     invoices no AHD_DATE elevators uk limited- ko...          Others
# 22     invoices no AHD_DATE elevators uk limited- ko...          Others
# 23    hello, please find in attach the invoice no AH...          Others
# 24    neopost invoice query hi all, the document bel...          Others
# 25    neopost invoice to be deleted hi all, the docu...          Others
# 26    overdue credit note and invoices importance: h...          Others
# 27    invoice AHD_NUMBER from control applications l...          Others
# 28    kone plc good afternoon, please can you confir...          Status
# 29    over due and due invoices for payment good aft...      Escalation
# ...                                                 ...             ...
# 8714                                                NaN          Others
# 8715  outstanding items dear all, i have been chasin...      Escalation
# 8716  invoice AHD_NUMBER good afternoon please find ...          Status
# 8717  hi team, please check with sharon kennedy rega...          Others
# 8718                                                NaN          Others
# 8719                                                NaN          Others
# 8720   sub: thank you for your request:  gunnebo sta...          Others
# 8721  warning: the sender of this email could not be...          Others
# 8722                    copy of invoice AHD_NUMBER null          Others
# 8723                                                NaN          Others
# 8724  we need an urgent response. especially the feb...          Others
# 8725  over deducted cis payments good morning it is ...          Others
# 8726                                 c&r lifts services          Others
# 8727                                                NaN          Others
# 8728                                                NaN          Others
# 8729  cis statement AHD_NUMBER AHD_ALPHANUM to AHD_N...          Others
# 8730  cis statement AHD_NUMBER AHD_ALPHANUM to AHD_N...          Others
# 8731  cis statement AHD_NUMBER AHD_ALPHANUM to AHD_N...          Others
# 8732                           eagle overseas statement          Others
# 8733                                                NaN          Others
# 8734                                                NaN          Others
# 8735                                     kone statement          Others
# 8736  hi, could you please push back to the vendor, ...          Others
# 8737  good afternoon, please find account statement ...          Others
# 8738  gs culleton - invoicing error good morning, i ...          Others
# 8739  hi all, many thanks for your recent remittance...          Status
# 8740  AHD_ALPHANUM hi team, please push back to vend...          Others
# 8741                                                NaN          Others
# 8742  invoice hi ian, we have another invoice which ...          Others
# 8743  AHD_NUMBER urgent letters received at keighley...          Others
#
#       Predicted Score
# 0               100.0
# 1                95.0
# 2               100.0
# 3               100.0
# 4               100.0
# 5                95.0
# 6               100.0
# 7                62.0
# 8                62.0
# 9               100.0
# 10               95.0
# 11              100.0
# 12              100.0
# 13              100.0
# 14              100.0
# 15              100.0
# 16               95.0
# 17              100.0
# 18              100.0
# 19              100.0
# 20              100.0
# 21              100.0
# 22              100.0
# 23              100.0
# 24              100.0
# 25              100.0
# 26              100.0
# 27              100.0
# 28               95.0
# 29               67.0
# ...               ...
# 8714            100.0
# 8715             73.0
# 8716             90.0
# 8717            100.0
# 8718            100.0
# 8719            100.0
# 8720            100.0
# 8721            100.0
# 8722            100.0
# 8723            100.0
# 8724            100.0
# 8725            100.0
# 8726            100.0
# 8727            100.0
# 8728            100.0
# 8729            100.0
# 8730            100.0
# 8731            100.0
# 8732            100.0
# 8733            100.0
# 8734            100.0
# 8735            100.0
# 8736            100.0
# 8737            100.0
# 8738            100.0
# 8739             85.0
# 8740            100.0
# 8741            100.0
# 8742            100.0
# 8743            100.0
#
# [8744 rows x 6 columns]

# %%
# df['parsed'] = "".apply(nlp)
print(nlp(df.text[2]))
txt=df['text']

# df.text.apply(nlp)
# Out:
# statement from oasis products vending services ltd for kone plc AHD_ALPHANUM

# %%
print("Document Count")
print(df.groupby('Predicted Class')['text'].count())
print("Word Count")
df.groupby('Predicted Class').apply(lambda x: x.text.apply(lambda x: len(x.split())).sum())
# Out:
# Document Count
# Predicted Class
# Escalation     434
# Others        5615
# Status         832
# Name: text, dtype: int64
# Word Count
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     688             try:
# --> 689                 result = self._python_apply_general(f)
#     690             except Exception:
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     189             group_axes = _get_axes(group)
# --> 190             res = f(group)
#     191             if not _is_indexed_like(res, group_axes):
#
# <ipython-input-61-772b54c02b18> in <lambda>(x)
#       3 print("Word Count")
# ----> 4 df.groupby('Predicted Class').apply(lambda x: x.text.apply(lambda x: len(x.split())).sum())
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-61-772b54c02b18> in <lambda>(x)
#       3 print("Word Count")
# ----> 4 df.groupby('Predicted Class').apply(lambda x: x.text.apply(lambda x: len(x.split())).sum())
#
# AttributeError: 'float' object has no attribute 'split'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-772b54c02b18> in <module>
#       2 print(df.groupby('Predicted Class')['text'].count())
#       3 print("Word Count")
# ----> 4 df.groupby('Predicted Class').apply(lambda x: x.text.apply(lambda x: len(x.split())).sum())
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     699
#     700                 with _group_selection_context(self):
# --> 701                     return self._python_apply_general(f)
#     702
#     703         return result
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     705     def _python_apply_general(self, f):
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#     709         return self._wrap_applied_output(
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     188             # group might be modified
#     189             group_axes = _get_axes(group)
# --> 190             res = f(group)
#     191             if not _is_indexed_like(res, group_axes):
#     192                 mutated = True
#
# <ipython-input-61-772b54c02b18> in <lambda>(x)
#       2 print(df.groupby('Predicted Class')['text'].count())
#       3 print("Word Count")
# ----> 4 df.groupby('Predicted Class').apply(lambda x: x.text.apply(lambda x: len(x.split())).sum())
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-61-772b54c02b18> in <lambda>(x)
#       2 print(df.groupby('Predicted Class')['text'].count())
#       3 print("Word Count")
# ----> 4 df.groupby('Predicted Class').apply(lambda x: x.text.apply(lambda x: len(x.split())).sum())
#
# AttributeError: 'float' object has no attribute 'split'
