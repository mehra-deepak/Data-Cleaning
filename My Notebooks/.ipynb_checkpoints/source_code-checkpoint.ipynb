# %%
#importing the essential libraries
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans 
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#importing the dataset
dataset =pd.read_excel('cleaned_labelled_final.xlsx')

# %%
#concatinating id and trial count as key
dataset['key'] = dataset['Id'] + '_' +dataset['Trail_Count'].apply(str)

# %%
dataset.key
# Out:
# 0       02s1r00001acKkkAAE_1
# 1       02s1r00001acKkkAAE_2
# 2       02s1r00001blgJyAAI_1
# 3       02s1r00001blgJyAAI_2
# 4       02s1r00001blgcRAAQ_1
# 5       02s1r00001blgcRAAQ_2
# 6       02s1r00001blgcRAAQ_3
# 7       02s1r00001blgcRAAQ_4
# 8       02s1r00001blj0aAAA_2
# 9       02s1r00001blj6TAAQ_2
# 10      02s1r00001blj6TAAQ_3
# 11      02s1r00001blwqoAAA_1
# 12      02s1r00001blwqoAAA_2
# 13      02s1r00001blz0lAAA_2
# 14      02s1r00001bm0GBAAY_2
# 15      02s1r00001bm0GBAAY_3
# 16      02s1r00001bm1QWAAY_2
# 17      02s1r00001bm1QWAAY_3
# 18      02s1r00001bm2gQAAQ_2
# 19      02s1r00001bm2hiAAA_1
# 20      02s1r00001bm43aAAA_1
# 21      02s1r00001bm43aAAA_2
# 22      02s1r00001bm43aAAA_4
# 23      02s1r00001bm43aAAA_5
# 24      02s1r00001bm4yMAAQ_2
# 25      02s1r00001bm4yMAAQ_3
# 26      02s1r00001bm4yMAAQ_4
# 27      02s1r00001bm5uuAAA_1
# 28      02s1r00001bmBRoAAM_1
# 29      02s1r00001bmBRoAAM_2
#                 ...
# 7059    02s1r00001ft4toAAA_3
# 7060    02s1r00001ft4toAAA_4
# 7061    02s1r00001ft4uDAAQ_1
# 7062    02s1r00001ft4uDAAQ_2
# 7063    02s1r00001ft4uDAAQ_3
# 7064    02s1r00001ft4xMAAQ_1
# 7065    02s1r00001ft4xMAAQ_2
# 7066    02s1r00001ft4xqAAA_1
# 7067    02s1r00001ft4xqAAA_2
# 7068    02s1r00001ft4xqAAA_3
# 7069    02s1r00001ft5PuAAI_2
# 7070    02s1r00001ft5PuAAI_3
# 7071    02s1r00001ft5aOAAQ_1
# 7072    02s1r00001ft5aOAAQ_2
# 7073    02s1r00001ft5aOAAQ_3
# 7074    02s1r00001ft5aOAAQ_4
# 7075    02s1r00001ft6hQAAQ_1
# 7076    02s1r00001ft6hQAAQ_2
# 7077    02s1r00001ft6hQAAQ_6
# 7078    02s1r00001ft6nEAAQ_1
# 7079    02s1r00001ft6nEAAQ_2
# 7080    02s1r00001ft6nEAAQ_3
# 7081    02s1r00001ft6qwAAA_1
# 7082    02s1r00001ft7kpAAA_1
# 7083    02s1r00001ft8AiAAI_1
# 7084    02s1r00001ft8AiAAI_2
# 7085    02s1r00001ft96DAAQ_1
# 7086    02s1r00001ft9SnAAI_2
# 7087    02s1r00001ft9SnAAI_3
# 7088    02s1r00001ft9SnAAI_5
# Name: key, Length: 7089, dtype: object

# %%
dataset
# Out:
#                       Id                                            Subject  \
# 0     02s1r00001acKkkAAE                                  FW: Payment Query
# 1     02s1r00001acKkkAAE                                  FW: Payment Query
# 2     02s1r00001blgJyAAI                            FW: STATEMENT & QUERIES
# 3     02s1r00001blgJyAAI                            FW: STATEMENT & QUERIES
# 4     02s1r00001blgcRAAQ  FW: Statement from Oasis Products Vending Serv...
# 5     02s1r00001blgcRAAQ  FW: Statement from Oasis Products Vending Serv...
# 6     02s1r00001blgcRAAQ  FW: Statement from Oasis Products Vending Serv...
# 7     02s1r00001blgcRAAQ  FW: Statement from Oasis Products Vending Serv...
# 8     02s1r00001blj0aAAA                              EES UK CIS deductions
# 9     02s1r00001blj6TAAQ     FW: Securitas Invoice Processed Twice In Error
# 10    02s1r00001blj6TAAQ     FW: Securitas Invoice Processed Twice In Error
# 11    02s1r00001blwqoAAA            FW: OVERDUE INVOICE for VENDOR 70096356
# 12    02s1r00001blwqoAAA            FW: OVERDUE INVOICE for VENDOR 70096356
# 13    02s1r00001blz0lAAA                                            problem
# 14    02s1r00001bm0GBAAY                                    FW: CIS payment
# 15    02s1r00001bm0GBAAY                                    FW: CIS payment
# 16    02s1r00001bm1QWAAY  FW: Invoice 11967 from CONTROL APPLICATIONS LI...
# 17    02s1r00001bm1QWAAY  FW: Invoice 11967 from CONTROL APPLICATIONS LI...
# 18    02s1r00001bm2gQAAQ                                           Invoices
# 19    02s1r00001bm2hiAAA                                      Invoice Query
# 20    02s1r00001bm43aAAA  FW: Securitas Invoice Processed Twice In Error...
# 21    02s1r00001bm43aAAA  FW: Securitas Invoice Processed Twice In Error...
# 22    02s1r00001bm43aAAA  FW: Securitas Invoice Processed Twice In Error...
# 23    02s1r00001bm43aAAA  FW: Securitas Invoice Processed Twice In Error...
# 24    02s1r00001bm4yMAAQ           FW: Payment Query [ref:_CN-00001175:ref]
# 25    02s1r00001bm4yMAAQ           FW: Payment Query [ref:_CN-00001175:ref]
# 26    02s1r00001bm4yMAAQ           FW: Payment Query [ref:_CN-00001175:ref]
# 27    02s1r00001bm5uuAAA                Overdue Invoices - Accounts on hold
# 28    02s1r00001bmBRoAAM             FW: NortonÃ¢â‚¬â„¢s Outstanding Monies
# 29    02s1r00001bmBRoAAM             FW: NortonÃ¢â‚¬â„¢s Outstanding Monies
# ...                  ...                                                ...
# 7059  02s1r00001ft4toAAA  RE: Statement as at 31/03/2019 [ref:_CN-000082...
# 7060  02s1r00001ft4toAAA  RE: Statement as at 31/03/2019 [ref:_CN-000082...
# 7061  02s1r00001ft4uDAAQ  RE: Statement as at 31/03/2019 [ref:_CN-000082...
# 7062  02s1r00001ft4uDAAQ  RE: Statement as at 31/03/2019 [ref:_CN-000082...
# 7063  02s1r00001ft4uDAAQ  RE: Statement as at 31/03/2019 [ref:_CN-000082...
# 7064  02s1r00001ft4xMAAQ  VL: If the invoice is rejected to the Supplier...
# 7065  02s1r00001ft4xMAAQ  VL: If the invoice is rejected to the Supplier...
# 7066  02s1r00001ft4xqAAA   RE: Payment specification [ref:_CN-00007394:ref]
# 7067  02s1r00001ft4xqAAA   RE: Payment specification [ref:_CN-00007394:ref]
# 7068  02s1r00001ft4xqAAA   RE: Payment specification [ref:_CN-00007394:ref]
# 7069  02s1r00001ft5PuAAI  RE: Sub: Thank you for your request: FW: INVOI...
# 7070  02s1r00001ft5PuAAI  RE: Sub: Thank you for your request: FW: INVOI...
# 7071  02s1r00001ft5aOAAQ         RE: UNPAID INVOICES [ref:_CN-00010131:ref]
# 7072  02s1r00001ft5aOAAQ         RE: UNPAID INVOICES [ref:_CN-00010131:ref]
# 7073  02s1r00001ft5aOAAQ         RE: UNPAID INVOICES [ref:_CN-00010131:ref]
# 7074  02s1r00001ft5aOAAQ         RE: UNPAID INVOICES [ref:_CN-00010131:ref]
# 7075  02s1r00001ft6hQAAQ  RE: Thank you for your request: Kone Plc - inv...
# 7076  02s1r00001ft6hQAAQ  RE: Thank you for your request: Kone Plc - inv...
# 7077  02s1r00001ft6hQAAQ  RE: Thank you for your request: Kone Plc - inv...
# 7078  02s1r00001ft6nEAAQ        RE: Remittance query [ref:_CN-00010102:ref]
# 7079  02s1r00001ft6nEAAQ        RE: Remittance query [ref:_CN-00010102:ref]
# 7080  02s1r00001ft6nEAAQ        RE: Remittance query [ref:_CN-00010102:ref]
# 7081  02s1r00001ft6qwAAA         RE: UNPAID INVOICES [ref:_CN-00010131:ref]
# 7082  02s1r00001ft7kpAAA  RE: Thank you for your request: Invoice Paymen...
# 7083  02s1r00001ft8AiAAI       RE: YOUR LAST PAYMENT [ref:_CN-00010113:ref]
# 7084  02s1r00001ft8AiAAI       RE: YOUR LAST PAYMENT [ref:_CN-00010113:ref]
# 7085  02s1r00001ft96DAAQ                                 Remittance request
# 7086  02s1r00001ft9SnAAI  RE: Sub: Thank you for your request: Purchase ...
# 7087  02s1r00001ft9SnAAI  RE: Sub: Thank you for your request: Purchase ...
# 7088  02s1r00001ft9SnAAI  RE: Sub: Thank you for your request: Purchase ...
#
#                                                HtmlBody  \
# 0     Good Morning, Please could I have a response t...
# 1     Payment Query Good Morning, Thank you for your...
# 2     Please find attached copy of statement/queries...
# 3     STATEMENT & QUERIES Please find attached up to...
# 4     Statement from Oasis Products Vending Services...
# 5     FW: Statement from Oasis Products Vending Serv...
# 6     FW: Statement from Oasis Products Vending Serv...
# 7     Statement from Oasis Products Vending Services...
# 8     EES UK CIS deductions Hi, After speaking to Sh...
# 9     FW: Securitas Invoice Processed Twice In Error...
# 10    Securitas Invoice Processed Twice In Error Hi ...
# 11    Dear Sirs. Please respond with regards to the ...
# 12    OVERDUE INVOICE for VENDOR 70096356 Please adv...
# 13    problemHi Supplier number 70092339 Problem Ã¢â...
# 14                                      FW: CIS payment
# 15    CIS payment Hi Can you please solve this probl...
# 16    FW: Invoice 11967 from CONTROL APPLICATIONS LI...
# 17    Invoice 11967 from CONTROL APPLICATIONS LIMITE...
# 18    Invoices Vendor number -72060294 Can we know t...
# 19    Good Afternoon, Please see the attached email ...
# 20                                                  NaN
# 21    FW: Securitas Invoice Processed Twice In Error...
# 22    FW: Securitas Invoice Processed Twice In Error...
# 23    Securitas Invoice Processed Twice In Error Hi ...
# 24    FW: Payment Query [ref:_CN-00001175:ref]Hi Tea...
# 25    FW: Payment QueryGood Morning, Please could I ...
# 26    Payment Query Good Morning, Thank you for your...
# 27    Good Afternoon Could you please advise if the ...
# 28    Hello All, Please could you deal with the cust...
# 29    NortonÃ¢â‚¬â„¢s Outstanding Monies Avtar Can I...
# ...                                                 ...
# 7059  Statement as at 31/03/2019 [ref:_CN-00008229:r...
# 7060  Statement as at 31/03/2019 [ref:_CN-00008229:r...
# 7061  This is to be match to line #30 of PO 45248160...
# 7062  RE: Statement as at 31/03/2019 [ref:_CN-000082...
# 7063  RE: Statement as at 31/03/2019 [ref:_CN-000082...
# 7064  Hi, I mean you have paid too low amount and it...
# 7065  VL: If the invoice is rejected to the Supplier...
# 7066  Hi, There is no difference in the invoice, ple...
# 7067   FW: Payment specification [ref:_CN-00007394:ref]
# 7068  Payment specification [ref:_CN-00007394:ref] H...
# 7069  Sub: Thank you for your request: FW: INVOICE 2...
# 7070  Sub: Thank you for your request: FW: INVOICE 2...
# 7071  Can someone send me the Purchase order number ...
# 7072  FW: UNPAID INVOICES [ref:_CN-00010131:ref] Hi ...
# 7073  FW: UNPAID INVOICES [ref:_CN-00010131:ref] Hi ...
# 7074  FW: UNPAID INVOICES Hi Team Can you please hav...
# 7075  Hi there, Please refer to my previous email an...
# 7076  Sub: Thank you for your request: Kone Plc - in...
# 7077  PO# fully utilized Dear Sir/Madam Please find ...
# 7078  Good morning team, Many thanks for this report...
# 7079  RE: Remittance query [ref:_CN-00010102:ref] Hi...
# 7080  RE: Remittance query [ref:_CN-00010102:ref] FY...
# 7081  Hi Team Thanks for the info, please chase up t...
# 7082  Good Morning Please find attached our latest s...
# 7083  Hi, Many thanks for your reply.Be please advis...
# 7084  YOUR LAST PAYMENTGood morning, I have an issue...
# 7085  Good morning Thank you for your recent payment...
# 7086  Sub: Thank you for your request: Purchase orde...
# 7087  Sub: Thank you for your request: Purchase orde...
# 7088      Purchase order number p/o number - 4521687707
#
#                                 HtmlBody (Cleaned Data)  Trail_Count  \
# 0     good morning, please could i have a response t...            1
# 1     payment query good morning, thank you for your...            2
# 2     please find attached copy of statement/queries...            1
# 3     statement & queries please find attached up to...            2
# 4     statement from oasis products vending services...            1
# 5      statement from oasis products vending service...            2
# 6      statement from oasis products vending service...            3
# 7     statement from oasis products vending services...            4
# 8     ees uk cis deductions hi, after speaking to sh...            2
# 9      securitas invoice processed twice in error hi...            2
# 10    securitas invoice processed twice in error hi ...            3
# 11    dear sirs. please respond with regards to the ...            1
# 12    overdue invoice for vendor AHD_NUMBER please a...            2
# 13    problemhi supplier number AHD_NUMBER problem Ã...            2
# 14                                          cis payment            2
# 15    cis payment hi can you please solve this probl...            3
# 16     invoice AHD_NUMBER from control applications ...            2
# 17    invoice AHD_NUMBER from control applications l...            3
# 18    invoices vendor number AHD_ALPHANUM can we kno...            2
# 19    good afternoon, please see the attached email ...            1
# 20                                                  NaN            1
# 21     securitas invoice processed twice in error AH...            2
# 22     securitas invoice processed twice in errorhi ...            4
# 23    securitas invoice processed twice in error hi ...            5
# 24     payment query AHD_ALPHANUM team,the following...            2
# 25     payment querygood morning, please could i hav...            3
# 26    payment query good morning, thank you for your...            4
# 27    good afternoon could you please advise if the ...            1
# 28    hello all, please could you deal with the cust...            1
# 29    nortonÃ¢â‚¬â„¢s outstanding monies avtar can i...            2
# ...                                                 ...          ...
# 7059  statement as at AHD_DATE AHD_ALPHANUM hi susan...            3
# 7060  statement as at AHD_DATE AHD_ALPHANUM hi susan...            4
# 7061  this is to be match to line AHD_ALPHANUM of po...            1
# 7062   statement as at AHD_DATE AHD_ALPHANUM mckechn...            2
# 7063   statement as at AHD_DATE AHD_ALPHANUM mckechn...            3
# 7064  hi, i mean you have paid too low amount and it...            1
# 7065  vl: if the invoice is rejected to the supplier...            2
# 7066  hi, there is no difference in the invoice, ple...            1
# 7067                 payment specification AHD_ALPHANUM            2
# 7068  payment specification AHD_ALPHANUM hi susan, t...            3
# 7069  sub: thank you for your request:  invoice AHD_...            2
# 7070  sub: thank you for your request:  invoice AHD_...            3
# 7071  can someone send me the purchase order number ...            1
# 7072   unpaid invoices AHD_ALPHANUM hi neil, could y...            2
# 7073   unpaid invoices AHD_ALPHANUM hi lydia, below ...            3
# 7074   unpaid invoices hi team can you please have a...            4
# 7075  hi there, please refer to my previous email an...            1
# 7076  sub: thank you for your request: kone plc - in...            2
# 7077  po# fully utilized dear sir/madam please find ...            6
# 7078                                 good morning team,            1
# 7079           remittance query AHD_ALPHANUM hi claire,            2
# 7080                  remittance query AHD_ALPHANUM fyi            3
# 7081  hi team thanks for the info, please chase up t...            1
# 7082  good morning please find attached our latest s...            1
# 7083  hi, many thanks for your reply.be please advis...            1
# 7084  your last paymentgood morning, i have an issue...            2
# 7085  good morning thank you for your recent payment...            1
# 7086  sub: thank you for your request: purchase orde...            2
# 7087  sub: thank you for your request: purchase orde...            3
# 7088      purchase order number p/o number - AHD_NUMBER            5
#
#                        Category Manual Label                   key
# 0                             0   Escalation  02s1r00001acKkkAAE_1
# 1                             0       Others  02s1r00001acKkkAAE_2
# 2       Vendor Statement Status       Others  02s1r00001blgJyAAI_1
# 3       Vendor Statement Status       Status  02s1r00001blgJyAAI_2
# 4                Invoice Status       Others  02s1r00001blgcRAAQ_1
# 5                Invoice Status       Others  02s1r00001blgcRAAQ_2
# 6                Invoice Status       Others  02s1r00001blgcRAAQ_3
# 7                Invoice Status       Others  02s1r00001blgcRAAQ_4
# 8                             0       Others  02s1r00001blj0aAAA_2
# 9                             0       Others  02s1r00001blj6TAAQ_2
# 10                            0       Others  02s1r00001blj6TAAQ_3
# 11                            0       Status  02s1r00001blwqoAAA_1
# 12                            0       Status  02s1r00001blwqoAAA_2
# 13               Invoice Status       Others  02s1r00001blz0lAAA_2
# 14               Invoice Status       Others  02s1r00001bm0GBAAY_2
# 15               Invoice Status   Escalation  02s1r00001bm0GBAAY_3
# 16                    GR Issues     Status-A  02s1r00001bm1QWAAY_2
# 17                    GR Issues     Status-A  02s1r00001bm1QWAAY_3
# 18                    GR Issues       Status  02s1r00001bm2gQAAQ_2
# 19         PO Mismatches/Issues       Others  02s1r00001bm2hiAAA_1
# 20                          NaN       Others  02s1r00001bm43aAAA_1
# 21                          NaN       Others  02s1r00001bm43aAAA_2
# 22                          NaN       Others  02s1r00001bm43aAAA_4
# 23                          NaN       Others  02s1r00001bm43aAAA_5
# 24                          NaN       Others  02s1r00001bm4yMAAQ_2
# 25                          NaN   Escalation  02s1r00001bm4yMAAQ_3
# 26                          NaN       Others  02s1r00001bm4yMAAQ_4
# 27                    GR Issues       Status  02s1r00001bm5uuAAA_1
# 28               Payment Status       Others  02s1r00001bmBRoAAM_1
# 29               Payment Status       Status  02s1r00001bmBRoAAM_2
# ...                         ...          ...                   ...
# 7059                     Others       Others  02s1r00001ft4toAAA_3
# 7060                     Others       Others  02s1r00001ft4toAAA_4
# 7061                     Others       Others  02s1r00001ft4uDAAQ_1
# 7062                     Others       Others  02s1r00001ft4uDAAQ_2
# 7063                     Others       Others  02s1r00001ft4uDAAQ_3
# 7064                     Others       Others  02s1r00001ft4xMAAQ_1
# 7065                     Others       Others  02s1r00001ft4xMAAQ_2
# 7066                     Others       Others  02s1r00001ft4xqAAA_1
# 7067                     Others       Others  02s1r00001ft4xqAAA_2
# 7068                     Others       Others  02s1r00001ft4xqAAA_3
# 7069             Invoice Status       Others  02s1r00001ft5PuAAI_2
# 7070             Invoice Status       Others  02s1r00001ft5PuAAI_3
# 7071             Invoice Status       Status  02s1r00001ft5aOAAQ_1
# 7072             Invoice Status       Others  02s1r00001ft5aOAAQ_2
# 7073             Invoice Status       Others  02s1r00001ft5aOAAQ_3
# 7074             Invoice Status   Escalation  02s1r00001ft5aOAAQ_4
# 7075       PO Mismatches/Issues       Others  02s1r00001ft6hQAAQ_1
# 7076       PO Mismatches/Issues       Others  02s1r00001ft6hQAAQ_2
# 7077       PO Mismatches/Issues       Others  02s1r00001ft6hQAAQ_6
# 7078                     Others       Status  02s1r00001ft6nEAAQ_1
# 7079                     Others       Others  02s1r00001ft6nEAAQ_2
# 7080                     Others       Others  02s1r00001ft6nEAAQ_3
# 7081             Invoice Status   Escalation  02s1r00001ft6qwAAA_1
# 7082          Awaiting Invoices       Status  02s1r00001ft7kpAAA_1
# 7083                     Others       Status  02s1r00001ft8AiAAI_1
# 7084                     Others       Status  02s1r00001ft8AiAAI_2
# 7085                     Others       Others  02s1r00001ft96DAAQ_1
# 7086  Awaiting Invoice scanning       Others  02s1r00001ft9SnAAI_2
# 7087  Awaiting Invoice scanning       Status  02s1r00001ft9SnAAI_3
# 7088  Awaiting Invoice scanning       Others  02s1r00001ft9SnAAI_5
#
# [7089 rows x 8 columns]

# %%
ds = dataset[['Id','HtmlBody (Cleaned Data)','Trail_Count','key']]

# %%
print(ds)
# Out:
#                       Id                            HtmlBody (Cleaned Data)  \
# 0     02s1r00001acKkkAAE  good morning, please could i have a response t...
# 1     02s1r00001acKkkAAE  payment query good morning, thank you for your...
# 2     02s1r00001blgJyAAI  please find attached copy of statement/queries...
# 3     02s1r00001blgJyAAI  statement & queries please find attached up to...
# 4     02s1r00001blgcRAAQ  statement from oasis products vending services...
# 5     02s1r00001blgcRAAQ   statement from oasis products vending service...
# 6     02s1r00001blgcRAAQ   statement from oasis products vending service...
# 7     02s1r00001blgcRAAQ  statement from oasis products vending services...
# 8     02s1r00001blj0aAAA  ees uk cis deductions hi, after speaking to sh...
# 9     02s1r00001blj6TAAQ   securitas invoice processed twice in error hi...
# 10    02s1r00001blj6TAAQ  securitas invoice processed twice in error hi ...
# 11    02s1r00001blwqoAAA  dear sirs. please respond with regards to the ...
# 12    02s1r00001blwqoAAA  overdue invoice for vendor AHD_NUMBER please a...
# 13    02s1r00001blz0lAAA  problemhi supplier number AHD_NUMBER problem Ã...
# 14    02s1r00001bm0GBAAY                                        cis payment
# 15    02s1r00001bm0GBAAY  cis payment hi can you please solve this probl...
# 16    02s1r00001bm1QWAAY   invoice AHD_NUMBER from control applications ...
# 17    02s1r00001bm1QWAAY  invoice AHD_NUMBER from control applications l...
# 18    02s1r00001bm2gQAAQ  invoices vendor number AHD_ALPHANUM can we kno...
# 19    02s1r00001bm2hiAAA  good afternoon, please see the attached email ...
# 20    02s1r00001bm43aAAA                                                NaN
# 21    02s1r00001bm43aAAA   securitas invoice processed twice in error AH...
# 22    02s1r00001bm43aAAA   securitas invoice processed twice in errorhi ...
# 23    02s1r00001bm43aAAA  securitas invoice processed twice in error hi ...
# 24    02s1r00001bm4yMAAQ   payment query AHD_ALPHANUM team,the following...
# 25    02s1r00001bm4yMAAQ   payment querygood morning, please could i hav...
# 26    02s1r00001bm4yMAAQ  payment query good morning, thank you for your...
# 27    02s1r00001bm5uuAAA  good afternoon could you please advise if the ...
# 28    02s1r00001bmBRoAAM  hello all, please could you deal with the cust...
# 29    02s1r00001bmBRoAAM  nortonÃ¢â‚¬â„¢s outstanding monies avtar can i...
# ...                  ...                                                ...
# 7059  02s1r00001ft4toAAA  statement as at AHD_DATE AHD_ALPHANUM hi susan...
# 7060  02s1r00001ft4toAAA  statement as at AHD_DATE AHD_ALPHANUM hi susan...
# 7061  02s1r00001ft4uDAAQ  this is to be match to line AHD_ALPHANUM of po...
# 7062  02s1r00001ft4uDAAQ   statement as at AHD_DATE AHD_ALPHANUM mckechn...
# 7063  02s1r00001ft4uDAAQ   statement as at AHD_DATE AHD_ALPHANUM mckechn...
# 7064  02s1r00001ft4xMAAQ  hi, i mean you have paid too low amount and it...
# 7065  02s1r00001ft4xMAAQ  vl: if the invoice is rejected to the supplier...
# 7066  02s1r00001ft4xqAAA  hi, there is no difference in the invoice, ple...
# 7067  02s1r00001ft4xqAAA                 payment specification AHD_ALPHANUM
# 7068  02s1r00001ft4xqAAA  payment specification AHD_ALPHANUM hi susan, t...
# 7069  02s1r00001ft5PuAAI  sub: thank you for your request:  invoice AHD_...
# 7070  02s1r00001ft5PuAAI  sub: thank you for your request:  invoice AHD_...
# 7071  02s1r00001ft5aOAAQ  can someone send me the purchase order number ...
# 7072  02s1r00001ft5aOAAQ   unpaid invoices AHD_ALPHANUM hi neil, could y...
# 7073  02s1r00001ft5aOAAQ   unpaid invoices AHD_ALPHANUM hi lydia, below ...
# 7074  02s1r00001ft5aOAAQ   unpaid invoices hi team can you please have a...
# 7075  02s1r00001ft6hQAAQ  hi there, please refer to my previous email an...
# 7076  02s1r00001ft6hQAAQ  sub: thank you for your request: kone plc - in...
# 7077  02s1r00001ft6hQAAQ  po# fully utilized dear sir/madam please find ...
# 7078  02s1r00001ft6nEAAQ                                 good morning team,
# 7079  02s1r00001ft6nEAAQ           remittance query AHD_ALPHANUM hi claire,
# 7080  02s1r00001ft6nEAAQ                  remittance query AHD_ALPHANUM fyi
# 7081  02s1r00001ft6qwAAA  hi team thanks for the info, please chase up t...
# 7082  02s1r00001ft7kpAAA  good morning please find attached our latest s...
# 7083  02s1r00001ft8AiAAI  hi, many thanks for your reply.be please advis...
# 7084  02s1r00001ft8AiAAI  your last paymentgood morning, i have an issue...
# 7085  02s1r00001ft96DAAQ  good morning thank you for your recent payment...
# 7086  02s1r00001ft9SnAAI  sub: thank you for your request: purchase orde...
# 7087  02s1r00001ft9SnAAI  sub: thank you for your request: purchase orde...
# 7088  02s1r00001ft9SnAAI      purchase order number p/o number - AHD_NUMBER
#
#       Trail_Count                   key
# 0               1  02s1r00001acKkkAAE_1
# 1               2  02s1r00001acKkkAAE_2
# 2               1  02s1r00001blgJyAAI_1
# 3               2  02s1r00001blgJyAAI_2
# 4               1  02s1r00001blgcRAAQ_1
# 5               2  02s1r00001blgcRAAQ_2
# 6               3  02s1r00001blgcRAAQ_3
# 7               4  02s1r00001blgcRAAQ_4
# 8               2  02s1r00001blj0aAAA_2
# 9               2  02s1r00001blj6TAAQ_2
# 10              3  02s1r00001blj6TAAQ_3
# 11              1  02s1r00001blwqoAAA_1
# 12              2  02s1r00001blwqoAAA_2
# 13              2  02s1r00001blz0lAAA_2
# 14              2  02s1r00001bm0GBAAY_2
# 15              3  02s1r00001bm0GBAAY_3
# 16              2  02s1r00001bm1QWAAY_2
# 17              3  02s1r00001bm1QWAAY_3
# 18              2  02s1r00001bm2gQAAQ_2
# 19              1  02s1r00001bm2hiAAA_1
# 20              1  02s1r00001bm43aAAA_1
# 21              2  02s1r00001bm43aAAA_2
# 22              4  02s1r00001bm43aAAA_4
# 23              5  02s1r00001bm43aAAA_5
# 24              2  02s1r00001bm4yMAAQ_2
# 25              3  02s1r00001bm4yMAAQ_3
# 26              4  02s1r00001bm4yMAAQ_4
# 27              1  02s1r00001bm5uuAAA_1
# 28              1  02s1r00001bmBRoAAM_1
# 29              2  02s1r00001bmBRoAAM_2
# ...           ...                   ...
# 7059            3  02s1r00001ft4toAAA_3
# 7060            4  02s1r00001ft4toAAA_4
# 7061            1  02s1r00001ft4uDAAQ_1
# 7062            2  02s1r00001ft4uDAAQ_2
# 7063            3  02s1r00001ft4uDAAQ_3
# 7064            1  02s1r00001ft4xMAAQ_1
# 7065            2  02s1r00001ft4xMAAQ_2
# 7066            1  02s1r00001ft4xqAAA_1
# 7067            2  02s1r00001ft4xqAAA_2
# 7068            3  02s1r00001ft4xqAAA_3
# 7069            2  02s1r00001ft5PuAAI_2
# 7070            3  02s1r00001ft5PuAAI_3
# 7071            1  02s1r00001ft5aOAAQ_1
# 7072            2  02s1r00001ft5aOAAQ_2
# 7073            3  02s1r00001ft5aOAAQ_3
# 7074            4  02s1r00001ft5aOAAQ_4
# 7075            1  02s1r00001ft6hQAAQ_1
# 7076            2  02s1r00001ft6hQAAQ_2
# 7077            6  02s1r00001ft6hQAAQ_6
# 7078            1  02s1r00001ft6nEAAQ_1
# 7079            2  02s1r00001ft6nEAAQ_2
# 7080            3  02s1r00001ft6nEAAQ_3
# 7081            1  02s1r00001ft6qwAAA_1
# 7082            1  02s1r00001ft7kpAAA_1
# 7083            1  02s1r00001ft8AiAAI_1
# 7084            2  02s1r00001ft8AiAAI_2
# 7085            1  02s1r00001ft96DAAQ_1
# 7086            2  02s1r00001ft9SnAAI_2
# 7087            3  02s1r00001ft9SnAAI_3
# 7088            5  02s1r00001ft9SnAAI_5
#
# [7089 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer()

# %%
ds['HtmlBody (Cleaned Data)'].isnull().sum()
# Out:
# 1

# %%
ds.isnull().sum()
# Out:
# Id                         0
# HtmlBody (Cleaned Data)    1
# Trail_Count                0
# key                        0
# dtype: int64

# %%
ds.dropna(inplace = True)
# Out:
# C:\Users\850044344\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X = cv.fit_transform(ds['HtmlBody (Cleaned Data)'])

# %%
X
# Out:
# <7088x8282 sparse matrix of type '<class 'numpy.int64'>'
# 	with 244107 stored elements in Compressed Sparse Row format>

# %%
vect = TfidfVectorizer(stop_words='english', max_df=0.50, min_df=2)
X = vect.fit_transform(ds['HtmlBody (Cleaned Data)'])

# %%
ds.columns = ds.columns.str.replace(' ','_').str.lower()

# %%
ds.columns
# Out:
# Index(['id', 'htmlbody_(cleaned_data)', 'trail_count', 'key'], dtype='object')

# %%
import os
import sys
import numpy
from sklearn.svm import LinearSVC
from sklearn.metrics import confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import metrics
from sklearn.datasets import load_files
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
X_dense = X.todense()
coords = PCA(n_components=2).fit_transform(X_dense)
plt.scatter(coords[:, 0], coords[:, 1], c='m')
plt.show()

# %%
def top_tfidf_feats(row, features, top_n=20):
    topn_ids = np.argsort(row)[::-1][:top_n]
    top_feats = [(features[i], row[i]) for i in topn_ids]
    df = pd.DataFrame(top_feats, columns=['features', 'score'])
    return df
def top_feats_in_doc(X, features, row_id, top_n=25):
    row = np.squeeze(X[row_id].toarray())
    return top_tfidf_feats(row, features, top_n)

# %%
features = vect.get_feature_names()
print(top_feats_in_doc(X, features, 1, 10))
# Out:
#       features     score
# 0     ahd_date  0.325101
# 1     advising  0.277796
# 2       credit  0.274680
# 3      payment  0.252114
# 4  transaction  0.245642
# 5        avoid  0.232850
# 6      charges  0.232850
# 7       remain  0.227811
# 8       issued  0.219427
# 9      reverse  0.204786

# %%
def top_mean_feats(X, features,
grp_ids=None, min_tfidf=0.1, top_n=25):
    if grp_ids:
        D = X[grp_ids].toarray()
    else:
        D = X.toarray()
        
    D[D < min_tfidf] = 0
    tfidf_means = np.mean(D, axis=0)
    return top_tfidf_feats(tfidf_means, features, top_n)

# %%
print(top_mean_feats(X, features, top_n=10))
# Out:
#     features     score
# 0    invoice  0.061363
# 1    payment  0.036395
# 2   invoices  0.035646
# 3         hi  0.034130
# 4  statement  0.030689
# 5   attached  0.029898
# 6    request  0.028260
# 7       team  0.027579
# 8   ahd_date  0.026981
# 9     number  0.024027

# %%
from sklearn.cluster import KMeans
wcss =[]
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('wcss')
plt.show()

# %%
n_clusters = 3
clf = KMeans(n_clusters=n_clusters, max_iter=100, init='k-means++', n_init=1)
labels = clf.fit_predict(X)

# %%
labels
# Out:
# array([1, 1, 0, ..., 2, 0, 0])

# %%
X

# %%
X_dense = X.todense()
pca = PCA(n_components=2).fit(X_dense)
coords = pca.transform(X_dense)

# %%
label_colors = ["#2AB0E9", "#2BAF74", "#D7665E", "#CCCCCC", 
                "#D2CA0D", "#522A64", "#A3DB05", "#FC6514"]
colors = [label_colors[i] for i in labels]

# %%
plt.scatter(coords[:, 0], coords[:, 1], c=colors)

# %%
print(clf.labels_)
# Out:
# [1 1 0 ... 2 0 0]

# %%
plt.scatter(X[la])
